# %% [markdown]
# **Importing Libraries and Dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('diabetes.csv')
X=dataset.iloc[:, :-1].values
Y=dataset.iloc[:,-1].values

# %% [markdown]
# **Splitting Dataset**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

# %% [markdown]
# **Training DT Model** **bold text**

# %%
from sklearn.tree import DecisionTreeClassifier
DTC=DecisionTreeClassifier(criterion='entropy',random_state=0)
DTC.fit(X_train,Y_train)

# %% [markdown]
# **Testing DTC Model**

# %%
y_pred=DTC.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1),Y_test.reshape(len(Y_test),1)),1))

# %% [markdown]
# **Confusion Matrix and Accuracy_Score**

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(Y_test,y_pred)
print(confusion_matrix(Y_test,y_pred))
accuracy_score(Y_test,y_pred)
# Out:
# [[79 28]
#  [17 30]]
# 0.7077922077922078

# %%
TP=cm[0][0]
TN=cm[1][1]
FP=cm[0][1]
FN=cm[1][0]
accuracy_rate=(TP+TN)/(TP+TN+FP+FN)*100
Precision=TP/(TP+FP)*100
Recall=TP/(TP+FN)*100
F1_Score=2*Precision*Recall/(Precision+Recall)

# %%
print('Accuracy rate =',accuracy_rate)
print('Precision =',Precision)
print('Recall =',Recall)
print('F1_Score=',F1_Score)
# Out:
# Accuracy rate = 70.77922077922078
# Precision = 73.83177570093457
# Recall = 82.29166666666666
# F1_Score= 77.83251231527093
